# %%
import os
import ast
import csv
import pickle
import unicodedata
import ollama
import spacy
import json
import re
from keybert import KeyBERT

# %%
with open("documents/unstructured/world_of_warcraft/library.pkl", "rb") as f:
    library = pickle.load(f)

# %%
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(
    chunk_text,
    keyphrase_ngram_range=(1, 1),
    stop_words='english',
    top_n=5,
    use_maxsum=True,  # or use_mmr=True
    diversity=0.7     # if using use_mmr
)

# %%
def extract_concepts(text, model='mistral'):
    prompt = f"""
    You are an expert knowledge extraction agent. Given the following documentation text, extract a list of key **terms or concepts** that should be represented as **nodes** in a knowledge graph.

    Instructions:
    - Extract domain-relevant terms only (e.g., concepts, methods, tools, models, datasets, or key terminology).
    - Do not include general-purpose stopwords.
    - Do not include gneric terms.
    - Return only a clean JSON list of strings (e.g., ["Concept A", "Tool B", "Dataset C"]).
    - Do NOT return explanations or extra text—only the JSON list.

    Text:
    \"\"\"{text}\"\"\"

    Extracted nodes:
    """

    response = ollama.chat(
        model=model,
        messages=[{
            "role": "user",
            "content": prompt
        }]
    )

    return response['message']['content']

# %%
categories = [
    "Person", "Company", "Government Body", "title", "Research Group", "Scientific Concept", "Social Concept",
    "Theoretical Model", "Country", "City", "Continent", "Geographic Feature", "Facility", "Institution",
    "Book", "Article", "Chapter", "Section", "Law", "Legal Code", "File Name", "Reference", "Symbolic Expression",
    "Mathematical Function", "Algorithm", "Pseudocode", "Physical Item", "Tool", "Instrument", "Chemical",
    "Historical Event", "Scientific Discovery", "Accident", "Disaster", "War", "Battle", "Steps in a Method",
    "Biological Process", "Chemical Process", "Industrial Process", "Academic Field", "Genre", "Classification",
    "System of Knowledge", "Date", "Duration", "Period", "Number", "Unit", "Range", "Acronym", "Label", "Keyword",
    "Invention", "Patent", "Technical System"
]

# %%
def get_type(term, model='mistral'):
    category_list = "\n- " + "\n- ".join(categories)

    prompt = f"""
    You are a classification agent. Your task is to assign the given term to **exactly one** of the following categories:

    {category_list}

    Instructions:
    - Respond only with the category name. 
    - Do not explain your reasoning. 
    - Do not use a categorey that is not in the list of categories.
    - Only assign a single category.

    Term: "{term}"
    Category:
    """.strip()

    response = ollama.chat(
        model=model,
        messages=[{
            "role": "user",
            "content": prompt
        }]
    )

    return response['message']['content'].strip()

# %%
len(library)
# Out:
# 2185

# %%
list_of_concepts = []

for entry in library[:100]:
    list_of_concepts.append(extract_concepts(entry['text']))

all_items = set()

for line in list_of_concepts:
    parsed_list = ast.literal_eval(line)
    all_items.update(parsed_list)

# %%
all_items
# Out:
# {'1st-Level Character Wealth',
#  'Abilities',
#  'Abilities and Conditions',
#  'Ability Modifiers',
#  'Ability Score',
#  'Ability Scores',
#  'Abilitγ Modifi ers',
#  'Academγ of Arcane Sciences',
#  'Accusations',
#  'Actions in Combat',
#  'Admiral',
#  'Admiral Daelin Proudmoore',
#  'Admiral Proudmoore',
#  'Adventurer',
#  'Adventures',
#  'Adventuring Gear',
#  'Aedelas Blackmoore',
#  'Aegwgnn',
#  'Affiliation',
#  'Affiliation Rating',
#  'Affiliations',
#  'Age',
#  'Agilitgamma',
#  'Agility (Agγ)',
#  'Aging Effects',
#  'Alexstrasza',
#  'Alignment',
#  'Alliance',
#  'Alliance & Horde Compendium',
#  "Alliance Player's Guide",
#  'Alliance heroes',
#  'Alliance or Horde',
#  'Alligators',
#  'Amg',
#  'Amnesty',
#  'Ancestral Throne',
#  'Ancient',
#  'Ancient Gurubashi Trolls',
#  'Ancient troll edifice',
#  'Andrew Bates',
#  'Andrew Rowe',
#  'Anduin Lothar',
#  'Animal Companion',
#  'Animal Companion Abilities Master Level',
#  'Arathor',
#  'Arc',
#  'Arcana Unearthed',
#  'Arcane Communitγ (Aco)',
#  'Arcane Library',
#  'Arcane Magic',
#  'Arcane magic',
#  'Arcanist',
#  'Arcanist Spell Slots per Day',
#  'Arcanist Spells',
#  'Archimonde',
#  'Architecture',
#  "Archmage Kel'Thuzad",
#  'Archmage of Kirin Tor',
#  'Armor',
#  'Armor Class Modifi ers',
#  'Armor and Shields',
#  'Arthas',
#  'Arthaus',
#  'Ashenvale Forest',
#  'Asn',
#  'Assassin',
#  'Assassin Spell Slots per Day',
#  'Assassins',
#  'Atmosphere for a Warcraft game',
#  'Attack Bonus',
#  'Attack Roll Modifi ers',
#  'Auberdine',
#  'Azeroth',
#  "Azeroth's Burning Steppes",
#  'Azshara',
#  'Background',
#  'Badlands',
#  'Bael Modan',
#  'Bandits',
#  'Barbarian',
#  'Barrens',
#  'Barrow Dens',
#  'Battle',
#  'Battle of Mount Hjal',
#  'Bazaars',
#  'Bbn',
#  'Bears',
#  'Beastmaster',
#  'Bedrolls',
#  'Berserker',
#  'Bill Petras',
#  'Black Dragons',
#  'Black Morass',
#  'Black dragons',
#  'Blackhand the Destroger',
#  'Blackhand the Destroyer',
#  'Blackmoore',
#  'Blackrock Orcs',
#  'Blackrock Spire',
#  'Blackwater Raiders',
#  'Blasted Lands',
#  'Blizzard Entertainment',
#  "Blizzard's World of Warcraft MMORPG",
#  'Blood',
#  'Bloodgaem',
#  'Bloodlust',
#  'Blue dragons',
#  'Bob Fitch',
#  'Bog beasts',
#  'Bonus Spell Slots',
#  'Bootyg Bay',
#  'Bottom Line',
#  'Brackish water',
#  'Brom',
#  'Brothels',
#  'Bsr',
#  'Bst',
#  'Buildings',
#  'Burning Legion',
#  'Campaign',
#  'Campaigns',
#  'Canyons',
#  'Caravan',
#  'Carlo Arellano',
#  'Carrγing Capacitγ',
#  'Carrγing Loads',
#  'Casinos',
#  'Cathedral of Light',
#  'Cenarius',
#  'Centaur',
#  'Centaur raiding parties',
#  'Center of Dwarven Culture',
#  'Chapter 1',
#  'Chapter 18: Campaigns',
#  'Chapter 2: Races',
#  'Chapter 3: Classes',
#  'Chapter 5: Skills',
#  'Chapter 6: Feats',
#  'Chapter 7: Description',
#  'Character',
#  'Character Classes',
#  'Character Creation',
#  'Character Sheet',
#  'Character Wealth bγ Level',
#  "Character's Skill List",
#  'Charisma',
#  'Charisma (Cha)',
#  'Chimera',
#  'Chris Metzen',
#  'Citadel',
#  'Citizen',
#  'Citizens',
#  'City',
#  'Citγ',
#  'Class',
#  'Class Tools and Skill Kits',
#  'Classes',
#  'Clothing',
#  'Cloudless Skies',
#  'Colonization',
#  'Combat',
#  'Common Armor, Weapon and Shield Hardness and Hit Points',
#  'Communities',
#  'Community Rules',
#  'Community generation rules',
#  'Communitγ',
#  'Communitγ Abilitγ Score Cost',
#  'Communitγ Defense Score Bonuses',
#  'Communitγ Levels',
#  'Communitγ Reputation Score Bonuses',
#  'Communitγ Skills List',
#  'Communitγ Wealth Level',
#  'Conditions',
#  'Confl ict',
#  'Conflict',
#  'Continent',
#  'Convolutional Neural Networks',
#  'Core Mechanic',
#  'Craft',
#  'Craft DCs',
#  'Craggy',
#  'Craggy Mountains',
#  'Creature Size and Scale',
#  'Creatures',
#  'Crocolisks',
#  'Crops',
#  'Crstal Lakes',
#  'Cult of the Damned',
#  'Cultural Revolution',
#  'Current Climate',
#  'Cursed ancients',
#  'DMG',
#  'Dalaran',
#  'Dark Iron Dwarves',
#  'Dark Iron dwarves',
#  'Dark Portal',
#  'Darkshire',
#  'Darkshore',
#  'Darkspear Trolls',
#  'Data Augmentation',
#  'Deadwind Pass',
#  'Deadwind Pass (region)',
#  'Death',
#  'Death Knight',
#  'Deep Learning',
#  'Defenses',
#  'Defias Brotherhood',
#  'Demon',
#  'Demon Blood',
#  'Demonic energy',
#  'Demonic spirits',
#  'Demons',
#  'Description',
#  'Desolace',
#  'Developers',
#  'Dice',
#  'Die Roll',
#  'Difficulty Class (DC)',
#  'Disease',
#  'Divine Magic',
#  'Donning Armor',
#  'Doughty Ironforge Warriors',
#  'Draenei',
#  'Draenor',
#  'Drake',
#  'Druid',
#  'Druid Spells',
#  'Druids',
#  'Dst',
#  'Duelist',
#  'Dun Morogh',
#  'Durotan',
#  'Durotar',
#  "Durotar (orcs' territor)",
#  'Duskwood',
#  'Dust devils',
#  'Dustwallow Marsh',
#  'Dwarf',
#  'Dwarven Architecture',
#  'Dwarven Marksmen',
#  'Dwarven Patrols',
#  'Dwarven Prospectors',
#  'Dwarves',
#  "Dwarves' Lofty Origins",
#  'East',
#  'Eastern Lands',
#  'Ege of Sargeras',
#  'Elf',
#  'Ellen P',
#  'Elven Ranger',
#  'Elven Ranger Favored Enemies',
#  'Elven Ranger Spells Slots per Day',
#  'Elwynn Forest',
#  'Emerald Dream',
#  'Enchanted land',
#  'Endless Sands',
#  'Engineering',
#  'Enorme Ruin',
#  'Entertainment',
#  'Equipment',
#  'Equipping a Character',
#  'Everday Farmer and Merchant',
#  'Evil magic',
#  'Experience',
#  "Explorer's Guild",
#  'Explorers',
#  'Explosives and Gunpowder',
#  'Extreme',
#  'Faith',
#  'Fallen logs',
#  'Fallow land',
#  'Familiar',
#  'Familiar Abilities Master Level',
#  'Fans',
#  'Fantasy Roleplaying Supplements',
#  'Feats',
#  'Feature Extraction',
#  'Fel-Sworn',
#  'Fel-sworn',
#  'Fellow Player',
#  'Felwood',
#  'Fen',
#  'Fine-tuning',
#  'Fire-Gut Ogres',
#  'First Clues',
#  'First Edition',
#  'First War',
#  'Fish',
#  'Fishers',
#  'Fog of War',
#  'Food, Drink and Lodging',
#  'Foothold Citadel',
#  'Forbidding',
#  'Forest Canopy',
#  'Forested',
#  'Forgetten',
#  'Forsaken',
#  'Fortified Dalsh-Beran',
#  'Fortress',
#  'Frostmane Trolls',
#  'Frostmane trolls',
#  'Frostmourne',
#  'Frostsaber cats',
#  'Frostsaber panthers',
#  'Frostwolf clan',
#  'Furbolg',
#  'GM',
#  'GMs',
#  'Game',
#  'Game Mechanics',
#  "Gamma World Plaγer's Handbook",
#  'Gender',
#  'Ghost towns',
#  'Giant Pines',
#  'Gladiator',
#  'Gladiatorial Arenas',
#  'Glenn Rane',
#  'Gnolls',
#  'Gnome',
#  'Gnomes',
#  'Goblin',
#  'Goblin Merchants',
#  'Goblin Watchmen',
#  'Goblins',
#  'Gold',
#  'Goods',
#  'Goods and Services',
#  'Gra G Mountains',
#  'Grand Admiral Daelin Proudmoore',
#  'Graveyards',
#  'Great Forge',
#  'Great Sea',
#  'Green dragons',
#  'Grim Batol',
#  "Grim Batol's great walls and spires",
#  'Grim Ulang',
#  'Grom Hellscream',
#  'Guardians of Tirisfal',
#  "Gul'dan",
#  'Hall of Thanes',
#  'Hard Work',
#  'Harpies',
#  'Healer',
#  'Healer Spell Slots per Day',
#  'Healer Spells',
#  'Height',
#  'Hero',
#  'Hero Points',
#  'Hero points system',
#  'Heroic Feel',
#  'High',
#  'High Bluffs',
#  'High Elf',
#  'High Elves',
#  'High Fantasy Gaming',
#  'Highborne',
#  'Hippogriff',
#  'Hire Transport',
#  'Historgy and gazetteer',
#  'Hit Die',
#  'Hit Points',
#  'Hjal Summit',
#  'Hlr',
#  'Hnt',
#  'Holγ Light',
#  'Horde',
#  'Horde Orcs',
#  "Horde Player's Guide",
#  'Hot',
#  'Hruon Firesinger',
#  'Human',
#  'Human forces',
#  'Humans',
#  'Hunter',
#  'Hunter Companion Abilities Master Level',
#  'Illidan',
#  'Illidan Stormrage',
#  "Illidan Stormrage's new Well of Eternitγ",
#  'Image Processing',
#  'Immortality',
#  'Independent',
#  'Independent Caravans',
#  'Independent caravans',
#  'Industry',
#  'Infiltrator',
#  'Ingenuity',
#  'Inhospitable',
#  'Initiative',
#  'Injury',
#  'Injury and Death',
#  'Intellect',
#  'Intelligence (Int)',
#  'Introduction',
#  'Iron Forge',
#  'Ironforge',
#  'Ironforge Capital',
#  'Ironforge Dwarf',
#  'Ironforge Dwarves',
#  'Ironforge Prospectors',
#  'Ironforge dwarves',
#  'Items Affected bγ Magical Attacks',
#  'Ivorγ Tower of Karazhan',
#  'Jaina',
#  'Jaina Proudmoore',
#  'Jose Aello',
#  'Jungle',
#  'Jungle Troll',
#  'Jungle Trolls',
#  'Justin Thavirat',
#  'Kaldorei',
#  'Kalimdor',
#  "Kalimdor's north coast",
#  "Kalimdor's northeast",
#  "Kel'Thuzad",
#  'Khaz Modan',
#  "Kil'jaeden",
#  'Kile',
#  'King Anduin Wrγnn',
#  'King Magni',
#  'King Magni Bronzebeard',
#  'King Terenas',
#  'Knights of the Silver Hand',
#  'Kobolds',
#  'Kul Tiras navγ',
#  'Land',
#  'Lands of Confl ict',
#  'Lands of Mysterery',
#  'Lands of Mγsterγ',
#  'Large cats',
#  'Legal Information',
#  'Lich',
#  'Lich King',
#  "Lich King's crown",
#  "Lich King's throne",
#  'Life Spans',
#  'Lights',
#  'Living trees called ancients',
#  'Loch Modan',
#  'Locked Iron Door',
#  'Loggers',
#  'Lord Anduin Lothar',
#  'Lordaeron',
#  'Lordaeron architecture',
#  'Lost Temple',
#  'MM',
#  'Madness',
#  'Maelstrom',
#  'Mage',
#  'Mage Spells',
#  'Magic',
#  'Magic & Maγhem',
#  'Malfunction Effects',
#  'Malfurion',
#  'Malfurion Stormrage',
#  'Manag',
#  'Maneuverabilitγ Ratings',
#  'Manual of Monsters',
#  'Manγ Ironforge strongholds',
#  'Maraudon',
#  'Martial Prowess',
#  'Math',
#  'Medivh',
#  "Medivh's seat of power",
#  'Menethil Harbor',
#  'Metropolis',
#  'Mike Johnstone',
#  'Mike Tinneγ',
#  'Militarγ Communitγ (Mco)',
#  'Militia',
#  'Millennia',
#  'Modifier',
#  'Molten Span',
#  'Money',
#  'Monster',
#  'Monster Books',
#  "Monte Cook's Arcana Unearthed",
#  'Moonglade',
#  'Moonglade Forest Creatures',
#  'More Exotic Means',
#  'Mount',
#  'Mount Hjal',
#  'Mount Hγjal',
#  'Mountainous',
#  'Mounted Warrior',
#  'Mounts and Related Gear',
#  'Mulgore',
#  'Multi-Class',
#  'Multiplication',
#  'Mur Laffertγ',
#  'Murlocs',
#  'NPCs',
#  'Naga',
#  'Name',
#  'Native Species',
#  'Necromancer',
#  'Necromancer Spells',
#  'Necromancers',
#  'Nefarion',
#  "Ner'zhul",
#  'Nethergarde Keep',
#  'Neural Networks',
#  'New Concepts',
#  'Night',
#  'Night Elf',
#  'Night Elf Druid',
#  'Night Elves',
#  'Night elves',
#  'Nighthaven',
#  'Nightsaber',
#  'Nine races (gnomes, jungle trolls, undead Forsaken)',
#  'Nomadic People',
#  'Nordrassil',
#  'Northrend',
#  'Nozdormu',
#  'Number',
#  'Numerous Tunnels',
#  'OGL route',
#  'Ocean',
#  'Ogres',
#  'Online Discussion Forum',
#  'Open Game License',
#  'Open Game License (OGL)',
#  'Orc',
#  'Orc Shamans',
#  'Orc scouts',
#  'Orc warlocks',
#  'Orcs',
#  'Orgrim Doomhammer',
#  'Orgrimmar',
#  'Other Settings',
#  'Outland',
#  'Outpost',
#  'PC',
#  'PCs',
#  'Pal',
#  'Paladin',
#  'Paladin Spell Slots per Day',
#  'Paladin Spells',
#  'Patience',
#  'Peaceful regions in Azeroth',
#  'Percentile dice',
#  'Perpetual summer twilight',
#  'Physical Appearance',
#  'Pirate Vessels',
#  'Player',
#  'Populace',
#  'Port',
#  'Possible War Experiences',
#  'Pre-trained Models',
#  'Prepared Spells',
#  'Prestige Classes',
#  'Price',
#  'Priest',
#  'Priest Spells',
#  'Primarilγ',
#  'Prince Arthas',
#  'Protruding rocks',
#  "Quel'Thalas",
#  'Quilboar',
#  'RPG',
#  'Race',
#  'Races',
#  'Racial Abilitγ Modifi ers',
#  'Racial Class',
#  'Racial Levels',
#  'Racial Tensions',
#  'Ragnaros the Fire Lord',
#  'Random Height and Weight',
#  'Random Starting Ages',
#  'Ratchet',
#  'Redridge Mountains',
#  'Religious Communitγ (Rco)',
#  'Renegade Brethren',
#  'Renegade humans',
#  'Renegade orcs',
#  'René & Michel Koiter',
#  'Resources',
#  'Restaurants',
#  'Revised Edition',
#  'Rich agricultural center',
#  'Rob Baxter',
#  'Rock golems',
#  'Rog',
#  'Rogue',
#  'Roleplaying Experience',
#  'Roleplaying Game',
#  'Roman Kenneγ',
#  'Rule',
#  'Rules Add-ons',
#  'Saboteurs',
#  'Sacred Forests',
#  'Salt deposits',
#  'Same Rules System',
#  'Samwise Didier',
#  'Sapphire Moonwells',
#  'Sargeras',
#  "Sargeras' spirit",
#  "Sargeras' tomb",
#  'Satyrs',
#  'Saving Throws',
#  'Scourge',
#  'Scout',
#  'Sct',
#  'Sea giants',
#  'Searing Gorge',
#  'Second War',
#  'Secrecy',
#  'Semi Kim',
#  'Services',
#  'Seth Johnson',
#  'Settings',
#  'Settlement',
#  'Settlements',
#  'Severe Winds',
#  'Shadow Council',
#  'Shadows & Light',
#  'Shaman',
#  'Shaman Spells',
#  'Shamanism',
#  'Shamanistic culture',
#  'Shields',
#  'Ship',
#  'Ships',
#  'Shipwards',
#  'Shops',
#  'Silithid',
#  'Sir Uther Lightbringer',
#  'Six abilities scores (Strength, Stamina, Agility, Intellect, Spirit, Charisma)',
#  'Size Modifi ers',
#  'Skill Points',
#  'Skill Points per Level',
#  'Skills',
#  'Skirmishes',
#  'Slaughtered',
#  'Slinking Wolves',
#  'Slumber',
#  'Snow Swept',
#  'Social Economic Strata',
#  'Solitary existence',
#  'Special Abilitγ Tγpes',
#  'Speed (Spt)',
#  'Spell Lists',
#  'Spell slot system',
#  'Spell slots-based magic system',
#  'Spellcasting',
#  'Spellcraft',
#  'Spells',
#  'Spells for Hire',
#  'Spirit',
#  'Stamina',
#  'Stamina (Sta)',
#  'Steadfastness',
#  'Stewart Wieck',
#  'Stolen Citadel',
#  'Stonetalon Mountains',
#  'Stonevault Troggs',
#  'Stonewatch Keep',
#  'Stormwind',
#  'Stormwind Assassins',
#  'Stormwind Citie',
#  'Stormwind Citγ',
#  'Stormwind Keep',
#  "Stormwind's economy",
#  "Stormwind's people",
#  "Stormwind's territory",
#  "Stormwind's territorγ",
#  'Stranglethorn Vale',
#  'Strength',
#  'Strength (Str)',
#  'Sunwell',
#  'Swamp of Sorrows',
#  "Sword & Sorcery's Advanced Player's Guide",
#  "Sword & Sorcerγ's Advanced Plaγer's Guide",
#  'Sword and Sorcerγ',
#  'Sword and Sorcerγ Studio',
#  'Table 1-1: Ability Modifiers',
#  'Table 2-4: The Night Elf',
#  'Tactical Speed',
#  'Tainted moonwells',
#  'Tanaris Desert',
#  'Tauren',
#  'Taverns',
#  'Tea Rooms',
#  'Team',
#  'Technological Device Features',
#  'Technological Device Function Diffi cultγ Benchmarks',
#  'Technological Devices',
#  'Technological device creation rules',
#  'Technology',
#  'Tent Cities',
#  'Tergande Whisperwind',
#  'Terminology',
#  'Test Set',
#  'The Arcane Communitγ (Aco)',
#  'The Arena',
#  'The Aristocrat (Ari)',
#  'The Barrens',
#  'The Burning Steppes',
#  'The Civilian Communitγ (Cco)',
#  'The Commoner (Com)',
#  'The Expert (Exp)',
#  'The First War',
#  'The Forsaken',
#  'The Frozen Throne',
#  'The High Elf',
#  'The Ironforge Dwarf',
#  'The Jungle Troll',
#  'The Militarγ Communitγ (Mco)',
#  'The Night Elf',
#  'The Religious Communitγ (Rco)',
#  'The Scout',
#  'The Soldier (Sol)',
#  'The Tauren',
#  'The Tinker',
#  'The Undead',
#  'The Warrior',
#  'The Wetlands',
#  'The World of Warcraft RPG',
#  'Theramore',
#  'Theramore Alliance',
#  'Theramore Island',
#  'Theramore Isle',
#  "Theramore's approval",
#  'Third War',
#  'Thrall',
#  'Thunder Bluff',
#  'Timber',
#  'Time of Day',
#  'Tinker',
#  'Tinγ and Large Weapon Damage',
#  'Tirisfal',
#  'Titan Artifact',
#  'Titan Artifacts',
#  'Titan artifacts',
#  'Titan ruin',
#  'Titans',
#  'Tkr',
#  'Tom Jung',
#  'Tomb',
#  'Tomb of Sargeras',
#  'Towns',
#  'Tracking Modifiers',
#  'Trade',
#  'Trade Routes',
#  'Trade Skill Equivalents',
#  'Trademarks',
#  'Trail Rations',
#  'Transfer Learning',
#  'Transport Ships',
#  'Transportation',
#  'Travel',
#  'Travelers',
#  'Trees',
#  'Trevor Jacobs',
#  'Troggs',
#  'Troll',
#  'Truce',
#  'Turning Undead',
#  'Twisting Nether',
#  'Two Peaks',
#  'Two-Weapon Fighting Penalties',
#  'Types of campaigns',
#  'Tγrande Whisperwind',
#  'Uldaman',
#  'Undead',
#  'Undead Forsaken',
#  'Underground Passages',
#  'Unexplored',
#  'Uniqueness',
#  'Upper Levels',
#  'Use Technological Device Check DCs',
#  'Validation Set',
#  'Venture Companγ',
#  'Vicious Defense',
#  'Villages and Towns',
#  'Violence',
#  'Violent Rainstorms',
#  'Vital Statistics',
#  'War',
#  'War Fleets',
#  'War of the Ancients',
#  'Warchief',
#  'Warchief Thrall',
#  'Warcraft',
#  'Warcraft Campaigns',
#  'Warcraft Computer Games',
#  'Warcraft Game',
#  'Warcraft RPG',
#  'Warcraft RPG Supplements',
#  'Warcraft computer games',
#  'Warcraft games',
#  'Warcraft universe',
#  'WarcraftRPG.com',
#  'Warlock',
#  'Warlock Spells',
#  'Warlocks',
#  'Warrior',
#  'Warriors',
#  'Warsong clan',
#  'Waterskins',
#  'Weapons',
#  'Weight',
#  'Weight Limit',
#  'Well of Eternity',
#  'Well of Eternitγ',
#  'West',
#  'Westfall',
#  'Wildhammer dwarves',
#  'Winterspring Valle',
#  'Wolves',
#  'Worgen',
#  'World Tree',
#  'World of Warcraft',
#  'World of Warcraft (RPG)',
#  'World of Warcraft MMORPG',
#  'World of Warcraft RPG',
#  'World of Warcraft the RPG',
#  'World of Warcraft the Roleplaying Game',
#  'WorldOfWarcraft',
#  'Wormbog',
#  'Writers',
#  'Wyvern',
#  'Young Orcs',
#  'Ysera',
#  'Zeppelin',
#  'arcane magic',
#  'armγ',
#  'artifacts',
#  'bandits',
#  'basic concepts',
#  'battles over land',
#  'bloodlust rage',
#  'bγ rich parents',
#  'canγons',
#  'caravans',
#  'centaur',
#  'characters',
#  "characters' backgrounds",
#  'citizens',
#  'civil war',
#  'community of Kaldorei',
#  'cosmology',
#  'd10',
#  'd12',
#  'd20',
#  'd4',
#  'd6',
#  'd8',
#  'death knights',
#  'debaucherγ',
#  'demon blood',
#  'demonic influence',
#  'demons',
#  'demons kill',
#  'demons local to Sargeras',
#  'divine magic',
#  'divine nature magic',
#  'dragons',
#  'dustγ landscape',
#  'dwarven marksmen',
#  'dwarven patrols',
#  'dwarves',
#  'east',
#  'enormous freshwater lake',
#  'fi rmlγ',
#  'fi sh',
#  'fight',
#  'flight of red dragons',
#  'foolhardy actions',
#  'fortified citγ',
#  'game concepts',
#  'gnomes',
#  'goals',
#  'goblin citγ',
#  'graveyards',
#  'greater power',
#  'heartland',
#  'heroes',
#  'high elves',
#  'human settlement',
#  'humans',
#  'inhospitable',
#  'jungle trolls',
#  'lands',
#  'law',
#  'lions',
#  'lumber mistake',
#  'magic',
#  'massive fortress',
#  'matt milberger',
#  'mercantile strength',
#  'mercy',
#  'misunderstandings',
#  'modifier',
#  'mood',
#  'morals',
#  'mortal races',
#  'murlocs',
#  'naga',
#  'nature-loving',
#  'necromancers',
#  'new concepts',
#  'new homeland',
#  'newer Alliance',
#  'night elf village',
#  'night elves',
#  'ocean',
#  'ogres',
#  'old night elf ruins',
#  'older Alliance',
#  'orc stronghold',
#  'orcs',
#  'ore',
#  'other affi liations',
#  'other races',
#  'patriotism',
#  'percentile dice',
#  'problem',
#  'quilboar tribes',
#  'racial war',
#  'raiding parties',
#  'rains',
#  'rockγ area',
#  'rockγ beaches',
#  'rogue Horde bands',
#  'rugged wilderness',
#  'sea giants',
#  'secret power',
#  'shamanistic',
#  'ships',
#  'shipwards',
#  'soldiers',
#  'steel-graγ skγ',
#  'target number',
#  'tauren',
#  'tauren tribe',
#  'thunder lizards',
#  'timber',
#  'towns',
#  'trade routes',
#  'tranquility',
#  'trogg band',
#  'undead',
#  'underground',
#  'victor',
#  'villages',
#  'violence',
#  'war',
#  'war experiences',
#  'war veterans',
#  'warlocks',
#  'warriors',
#  'wild creatures',
#  'winds',
#  "world's history"}

# %%
item_types = []

for item in all_items:
    _type = get_type(item)
    item_types.append((item,_type))

# %%
item_types
# Out:
# [('Armor Class Modifi ers', 'Algorithm'),
#  ('Khaz Modan', 'Geographic Feature'),
#  ('Green dragons', 'Social Concept'),
#  ('Fog of War', 'Battle'),
#  ('Stonevault Troggs',
#   "Band (or possibly, a fictional band if it's from a book, movie, or game)"),
#  ('racial war', 'War'),
#  ('Ironforge Prospectors', 'Company'),
#  ('Bloodgaem', 'Symbolic Expression'),
#  ('Trees', 'Geographic Feature'),
#  ('Communities', 'Social Concept'),
#  ('Fortress', 'Geographic Feature'),
#  ('arcane magic', 'Social Concept'),
#  ('Bob Fitch', 'Person'),
#  ("Theramore's approval", 'Title'),
#  ('Clothing',
#   'Geographic Feature (incorrect, but this is an exception due to common usage as a colloquial term for items used to cover bodies)\nCorrect Category: Physical Item'),
#  ('Naga', 'Geographic Feature'),
#  ('Steadfastness', 'Social Concept'),
#  ('Ironforge', 'Facility'),
#  ('Amg', 'Company'),
#  ('Communitγ Skills List', 'Social Concept'),
#  ('Craft',
#   'Artisanry (can be considered as a Social Concept or Facility, but Craft is more commonly associated with the latter)'),
#  ("Quel'Thalas", 'Geographic Feature'),
#  ('Nethergarde Keep', 'Facility'),
#  ('Nomadic People', 'Social Concept'),
#  ('The Tinker', 'Title'),
#  ('Millennia', 'Period'),
#  ('Ancient Gurubashi Trolls',
#   'Fantasy Race (not included in the provided categories, but closest match)'),
#  ('mercy', 'Social Concept'),
#  ('Spell Lists', 'Book'),
#  ('Night', 'Geographic Feature'),
#  ('Dwarven Prospectors', 'Title'),
#  ('Cursed ancients', 'Social Concept'),
#  ('Heroic Feel', 'Social Concept'),
#  ('Dark Iron Dwarves', 'Fantasy Race'),
#  ('Initiative', 'Social Concept'),
#  ('Large cats', 'Geographic Feature'),
#  ('problem', 'Social Concept'),
#  ('Confl ict', 'Conflict (Category)'),
#  ('Battle',
#   "Battle\n\nHere's the list again for easy reference:\n\n- Person\n- Company\n- Government Body\n- title\n- Research Group\n- Scientific Concept\n- Social Concept\n- Theoretical Model\n- Country\n- City\n- Continent\n- Geographic Feature\n- Facility\n- Institution\n- Book\n- Article\n- Chapter\n- Section\n- Law\n- Legal Code\n- File Name\n- Reference\n- Symbolic Expression\n- Mathematical Function\n- Algorithm\n- Pseudocode\n- Physical Item\n- Tool\n- Instrument\n- Chemical\n- Historical Event\n- Scientific Discovery\n- Accident\n- Disaster\n- War\n- Battle\n- Steps in a Method\n- Biological Process\n- Chemical Process\n- Industrial Process\n- Academic Field\n- Genre\n- Classification\n- System of Knowledge\n- Date\n- Duration\n- Period\n- Number\n- Unit\n- Range\n- Acronym\n- Label\n- Keyword\n- Invention\n- Patent\n- Technical System"),
#  ('Malfurion Stormrage', 'Character'),
#  ('flight of red dragons', 'Social Concept'),
#  ('Stamina', 'Scientific Concept'),
#  ('Ancestral Throne', 'Social Concept'),
#  ('Giant Pines', 'Geographic Feature'),
#  ('Industry', 'Industry - Economic Sector'),
#  ('rockγ beaches', 'Geographic Feature'),
#  ('armγ', 'Mathematical Function'),
#  ('Maraudon', 'Geographic Feature'),
#  ('Size Modifi ers', 'Mathematical Function'),
#  ('Dustwallow Marsh', 'Geographic Feature'),
#  ('Abilitγ Modifi ers', 'Algorithm'),
#  ('Sapphire Moonwells', 'Geographic Feature'),
#  ('Bonus Spell Slots', 'Algorithm'),
#  ('Technological Device Function Diffi cultγ Benchmarks',
#   'Scientific Concept'),
#  ('Warcraft RPG Supplements',
#   'Game\n\nExplanation: Warcraft RPG Supplements are related to a specific game, in this case, World of Warcraft Role Playing Game (RPG), and are not categorized as any other item on the list.'),
#  ('Assassins', 'Historical Event'),
#  ('Communitγ Levels', 'Social Concept'),
#  ('Alligators',
#   "Animal (not explicitly listed, but can be subsumed under 'Geographic Feature' or 'Wildlife', both of which are not included in the given list)"),
#  ('Young Orcs', 'Social Concept'),
#  ('Arcanist Spells', 'Social Concept'),
#  ('Ability Score', 'Scientific Concept'),
#  ('Bst', 'File Name'),
#  ('Demons', 'Social Concept'),
#  ('Trademarks', 'Company'),
#  ('1st-Level Character Wealth', 'Game Mechanic'),
#  ('Conflict', 'Social Concept'),
#  ('Death', 'Social Concept'),
#  ('Six abilities scores (Strength, Stamina, Agility, Intellect, Spirit, Charisma)',
#   'Scientific Concept'),
#  ('Trevor Jacobs', 'Person'),
#  ('Rules Add-ons', 'Algorithm'),
#  ('misunderstandings', 'Social Concept'),
#  ('Battle of Mount Hjal', 'Battle'),
#  ('Intelligence (Int)', 'Scientific Concept'),
#  ('Chapter 5: Skills', 'Chapter'),
#  ('Hunter Companion Abilities Master Level', 'Game Mechanism'),
#  ('ore', 'Geographic Feature'),
#  ('Emerald Dream', 'Social Concept'),
#  ('Lordaeron architecture', 'Architectural Concept'),
#  ('Types of campaigns', 'Social Concept'),
#  ('Roleplaying Experience', 'Social Concept'),
#  ('Attack Bonus', 'Algorithm'),
#  ('Character', 'Character - Social Concept'),
#  ('Enorme Ruin', 'Geographic Feature'),
#  ('mercantile strength', 'Social Concept'),
#  ('Common Armor, Weapon and Shield Hardness and Hit Points',
#   'Scientific Concept'),
#  ('Grim Ulang', 'Title'),
#  ("Azeroth's Burning Steppes", 'Geographic Feature'),
#  ('War', 'War\n\nCategory: Historical Event / Battle'),
#  ('winds', 'Geographic Feature'),
#  ('Fire-Gut Ogres', 'Fiction (Character)'),
#  ('villages', 'Geographic Feature'),
#  ('Dun Morogh', 'Geographic Feature'),
#  ('Warsong clan', 'Social Concept'),
#  ('Fel-sworn',
#   "Title (assuming it's a character or group from a book, article, chapter, etc.)"),
#  ('Animal Companion', 'Social Concept'),
#  ('Westfall', 'Person'),
#  ('Ironforge Capital', 'Company'),
#  ("Gamma World Plaγer's Handbook", 'Book'),
#  ('Violence', 'Social Concept'),
#  ('Second War', 'War'),
#  ('Citadel', 'City or Geographic Feature'),
#  ('The Ironforge Dwarf', 'Character (Person)'),
#  ('First Edition', 'Book'),
#  ('Theramore Isle', 'Geographic Feature'),
#  ('Chapter 3: Classes', 'Chapter'),
#  ('Core Mechanic', 'Algorithm'),
#  ('Trade Routes', 'Geographic Feature'),
#  ('Goblins', 'Social Concept'),
#  ('Theramore Alliance', 'Alliance'),
#  ("Horde Player's Guide", 'Book'),
#  ('Tomb', 'Geographic Feature'),
#  ('Vicious Defense', 'War'),
#  ('Molten Span', 'Geographic Feature'),
#  ('The Expert (Exp)', 'title'),
#  ('Alignment', 'Social Concept'),
#  ('Highborne',
#   'Fantasy Character (not explicitly listed, but closest match in the provided categories)'),
#  ('Snow Swept', 'Geographic Feature'),
#  ('Dalaran', 'City'),
#  ('Redridge Mountains', 'Geographic Feature'),
#  ('Classes', 'Academic Field'),
#  ('Faith', 'Social Concept'),
#  ('Burning Legion',
#   'Fictional Entity (not present in the provided categories, but closest match)'),
#  ('Money', 'Currency (a subcategory of Financial Concept)'),
#  ('orcs', 'Fantasy Creature'),
#  ('Frostmourne', 'Fantasy Fictional Item (not listed, but closest match)'),
#  ('Canyons', 'Geographic Feature'),
#  ('Quilboar', 'Social Concept'),
#  ('Writers', 'Person'),
#  ('Food, Drink and Lodging', 'Social Concept'),
#  ('Engineering', 'Scientific Concept'),
#  ('Taverns', 'City or Geographic Feature'),
#  ('fi rmlγ', 'Symbolic Expression'),
#  ('Affiliation Rating', 'System of Knowledge'),
#  ('Militarγ Communitγ (Mco)', 'Research Group'),
#  ('fortified citγ', 'Geographic Feature'),
#  ('Creatures', 'Social Concept'),
#  ('Archimonde', 'Fantasy Character'),
#  ('Injury and Death', 'Disaster'),
#  ('Academγ of Arcane Sciences', 'Research Group'),
#  ('Fine-tuning', 'Algorithm'),
#  ('Nordrassil', 'Geographic Feature'),
#  ('Black Dragons', 'Social Concept'),
#  ('timber', 'Geographic Feature'),
#  ('High Fantasy Gaming', 'Genre'),
#  ('Armor and Shields', 'Geographic Feature (Historical)'),
#  ('Illidan',
#   'Character (from context, it\'s likely a fictional character, but without more specific information, I can\'t narrow it down to a more specific category such as "Video Game Character")'),
#  ('Humans', 'Person'),
#  ('Fortified Dalsh-Beran', 'Facility'),
#  ('Introduction', 'Section'),
#  ('Glenn Rane', 'Person'),
#  ('Goods and Services', 'Economic Concept'),
#  ('Stormwind Citie', 'City'),
#  ('Class Tools and Skill Kits', 'Facility'),
#  ('Magic & Maγhem', 'Book'),
#  ('Doughty Ironforge Warriors', 'Character (Faction)'),
#  ('Use Technological Device Check DCs', 'Pseudocode'),
#  ('Blackmoore', 'City'),
#  ('The Barrens', 'Geographic Feature'),
#  ("Stormwind's economy", 'Social Concept'),
#  ('naga', 'Geographic Feature'),
#  ('shamanistic', 'Social Concept'),
#  ('Alliance or Horde', 'Game (or Historical Event)'),
#  ("Sword & Sorcerγ's Advanced Plaγer's Guide", 'Book'),
#  ('Sir Uther Lightbringer', 'title'),
#  ('Horde Orcs',
#   'Fictional Entity (not in the given list, but could be considered as a subcategory of either "Social Concept" or "Character", depending on context)'),
#  ('Maneuverabilitγ Ratings', 'Mathematical Function'),
#  ('Deadwind Pass', 'Geographic Feature'),
#  ('Aging Effects', 'Scientific Concept'),
#  ("Kel'Thuzad", 'title'),
#  ('Peaceful regions in Azeroth', 'Geographic Feature'),
#  ('new concepts', 'Social Concept'),
#  ('heroes', 'Social Concept'),
#  ('Bael Modan', 'Geographic Feature'),
#  ('Titan artifacts', 'Geographic Feature'),
#  ('Kalimdor', 'Geographic Feature'),
#  ('Disease', 'Scientific Concept'),
#  ('Lights', 'Geographic Feature'),
#  ('Waterskins', 'Geographic Feature'),
#  ('Lands of Mγsterγ', 'Geographic Feature'),
#  ('Casinos', 'City, Facility'),
#  ('Campaigns', 'Social Concept'),
#  ('Entertainment', 'Social Concept'),
#  ('Communitγ', 'Social Concept'),
#  ('Zeppelin', 'Airship (Facility)'),
#  ("Medivh's seat of power",
#   "Fantasy Character (not listed, but can be considered as an extension of 'title')"),
#  ('Technology', 'Scientific Concept'),
#  ('World of Warcraft RPG', 'Game'),
#  ('Arcane Library', 'Institution'),
#  ('Animal Companion Abilities Master Level', 'Social Concept'),
#  ('Lord Anduin Lothar', 'Person'),
#  ('death knights', 'Fantasy Creature'),
#  ('Orc scouts', 'Fiction Character (not listed, but closest fit)'),
#  ('RPG', 'Game'),
#  ('Prestige Classes', 'Social Concept'),
#  ('Familiar', 'Social Concept'),
#  ('Race', 'Social Concept'),
#  ('Slumber', 'Social Concept'),
#  ('Tinker', 'Person'),
#  ('Online Discussion Forum', 'Social Concept'),
#  ('Knights of the Silver Hand', 'Title'),
#  ('Ivorγ Tower of Karazhan', 'Geographic Feature'),
#  ('First Clues', 'Steps in a Method'),
#  ('basic concepts', 'Social Concept'),
#  ('Fans', 'Social Concept'),
#  ('Skirmishes', 'Battle'),
#  ('lions', 'Geographic Feature'),
#  ('Orc warlocks',
#   'Fiction Character (a combination of Person and Fantasy Element)'),
#  ('Bog beasts', 'Social Concept'),
#  ('Druid', 'Person'),
#  ('Craft DCs', 'Algorithm'),
#  ('The Frozen Throne', 'Title'),
#  ('percentile dice', 'Mathematical Function'),
#  ('Speed (Spt)', 'Mathematical Function'),
#  ('Ratchet', 'Tool'),
#  ('Gold', 'Chemical'),
#  ('City', 'City'),
#  ('Sargeras', 'Mythological Figure'),
#  ('Evil magic', 'Social Concept'),
#  ('Intellect', 'Social Concept'),
#  ('Titans',
#   'Title (as it refers to a group of characters in mythology or a movie franchise)'),
#  ('Lands of Confl ict', 'Geographic Feature'),
#  ('Developers', 'Person, Company'),
#  ('Convolutional Neural Networks', 'Theoretical Model'),
#  ('King Magni', 'Person'),
#  ('old night elf ruins', 'Geographic Feature'),
#  ('Druid Spells', 'Social Concept'),
#  ('Solitary existence', 'Social Concept'),
#  ('Stranglethorn Vale', 'Geographic Feature'),
#  ('Chapter 1', 'Chapter'),
#  ('canγons', 'Mathematical Function'),
#  ('Night elves',
#   'Fantasy Race (not in provided categories, but closest match)'),
#  ('Revised Edition', 'Reference'),
#  ('Carrγing Loads', 'Scientific Concept'),
#  ('Gnomes', 'Social Concept'),
#  ('Searing Gorge', 'Geographic Feature'),
#  ('Blizzard Entertainment', 'Company'),
#  ('Transportation', 'Social Concept'),
#  ('Trade', 'Economy'),
#  ('Paladin Spell Slots per Day', 'Pseudocode'),
#  ('Land', 'Geographic Feature'),
#  ('Spells', 'Social Concept'),
#  ('Elven Ranger Spells Slots per Day', 'Pseudocode'),
#  ('Human', 'Person'),
#  ('Fantasy Roleplaying Supplements',
#   "Game\n\nFor future reference, I will categorize terms based on their primary function or nature as per the provided list. If a term doesn't fit any of these categories, it might be categorized as 'Other'."),
#  ("Blizzard's World of Warcraft MMORPG", 'Game'),
#  ('Bazaars', 'Social Concept'),
#  ('René & Michel Koiter', 'Person'),
#  ('war veterans', 'Person'),
#  ('Hnt', 'Symbolic Expression'),
#  ('d12', 'File Name'),
#  ('d10', 'File Name'),
#  ('enormous freshwater lake', 'Geographic Feature'),
#  ('Arcanist', 'Title'),
#  ('Ancient troll edifice', 'Geographic Feature'),
#  ('Mounted Warrior', 'Geographic Feature'),
#  ("Illidan Stormrage's new Well of Eternitγ",
#   'Fictional Entity (not listed but can be categorized under "Title", as it refers to a character from a work of fiction, specifically World of Warcraft)'),
#  ('Blood', 'Scientific Concept'),
#  ('morals', 'Social Concept'),
#  ('undead', 'Supernatural Concept'),
#  ('Sea giants', 'Geographic Feature'),
#  ('Weapons', 'War'),
#  ('d8', 'File Name'),
#  ('Agilitgamma', 'File Name'),
#  ('Monster Books', 'Book'),
#  ('Chapter 6: Feats', 'Chapter'),
#  ('WorldOfWarcraft', 'Game'),
#  ('Arc', 'Geographic Feature'),
#  ('night elf village', 'Geographic Feature'),
#  ('Crocolisks', 'Mythical Creature'),
#  ('Barbarian', 'Social Concept'),
#  ('lands', 'Geographic Feature'),
#  ('Great Forge', 'Facility'),
#  ('Ingenuity', 'Social Concept'),
#  ('Two Peaks', 'Geographic Feature'),
#  ('Jungle Troll', 'Social Concept'),
#  ('Arthas', 'Character'),
#  ('Divine Magic', 'Social Concept'),
#  ('Assassin', 'Title (or Historical Event)'),
#  ('Justin Thavirat', 'Person'),
#  ('Tactical Speed',
#   'Tactical Speed falls under the category of Military Concept or Strategic Concept.'),
#  ('Continent', 'Continent'),
#  ('towns', 'City'),
#  ('Healer', 'Person'),
#  ('community of Kaldorei', 'City'),
#  ('Death Knight',
#   'Character (from the list, this term best fits under the closest category "Person", but it\'s actually a fictional character from a game or book)'),
#  ('Price', 'Mathematical Function'),
#  ('Data Augmentation', 'Algorithm'),
#  ('Elven Ranger', 'Character (Fiction)'),
#  ('Charisma', 'Social Concept'),
#  ('Technological Device Features', 'Theoretical Model'),
#  ("Alliance Player's Guide", 'Book'),
#  ('Mount Hjal', 'Geographic Feature'),
#  ('Violent Rainstorms', 'Weather Event (Geographic Feature)'),
#  ('Explorers', 'Social Concept'),
#  ('Priest', 'Person'),
#  ('Saving Throws', 'Mathematical Function'),
#  ('Uniqueness', 'Social Concept'),
#  ('murlocs',
#   "Fictional Character (Not listed, but can be considered as a subcategory under 'Title' or 'Symbolic Expression')"),
#  ('Andrew Rowe', 'Person'),
#  ('Dst', 'Algorithm'),
#  ('Tauren', 'Character (Fantasy Fiction)'),
#  ('Multiplication', 'Mathematical Function'),
#  ("Archmage Kel'Thuzad", 'title'),
#  ('Fellow Player', 'Social Concept'),
#  ('Fish', 'Geographic Feature'),
#  ('Fallen logs', 'Geographic Feature'),
#  ('Hall of Thanes', 'Social Concept'),
#  ('War of the Ancients', 'Historical Event'),
#  ('Infiltrator', 'Social Concept'),
#  ('Jungle Trolls', 'Social Concept'),
#  ('Moonglade', 'Geographic Feature'),
#  ('Life Spans', 'Social Concept'),
#  ("Monte Cook's Arcana Unearthed", 'Book'),
#  ('Cathedral of Light', 'Facility'),
#  ('Equipping a Character', 'Social Concept'),
#  ('Agility (Agγ)', 'Scientific Concept'),
#  ('Rogue', 'Social Concept'),
#  ('Arcane magic', 'Social Concept'),
#  ('ocean', 'Geographic Feature'),
#  ('High Elves', 'Fantasy Race (not in given list, but closest fit)'),
#  ('Stolen Citadel', 'Geographic Feature'),
#  ('Ellen P', 'Person'),
#  ('Gladiator', 'Title'),
#  ('lumber mistake',
#   'Error\n\nI\'m sorry for any inconvenience, but the term "lumber mistake" does not fit any of the provided categories. It could be argued as an "Historical Event", "Accident", or even a "Biological Process" in a very abstract sense if we consider decay or deterioration of lumber as a biological process, but it is not one of the specific categories listed. I recommend rephrasing the question or providing a more specific term if possible.'),
#  ('Stonetalon Mountains', 'Geographic Feature'),
#  ('Night Elves',
#   'Fantasy Race (Not in provided categories, but closely related to "Scientific Concept", "Social Concept", "Theoretical Model" if we consider it as a fictional race from a game or book)'),
#  ('DMG', 'Company'),
#  ('Orc', 'Fictional Character'),
#  ('The Warrior', 'Person'),
#  ('Legal Information', 'Legal Code'),
#  ('Skill Points', 'Game Mechanism'),
#  ('Shamanism', 'Scientific Concept'),
#  ('Well of Eternitγ', 'Geographic Feature'),
#  ('Strength', 'Social Concept'),
#  ('High Elf', 'Character (Fantasy Race)'),
#  ('Secrecy', 'Social Concept'),
#  ('Rule', 'Algorithm'),
#  ('Forested', 'Geographic Feature'),
#  ('Frostsaber panthers', 'Social Concept'),
#  ('magic', 'Social Concept'),
#  ('Prince Arthas', 'Person'),
#  ('Turning Undead', 'Social Concept'),
#  ('Ghost towns', 'Geographic Feature'),
#  ("Kalimdor's northeast", 'Geographic Feature'),
#  ('Special Abilitγ Tγpes', 'Scientific Concept'),
#  ('Independent Caravans', 'Social Concept'),
#  ('Necromancer Spells', 'Social Concept'),
#  ('Grom Hellscream', 'Character'),
#  ('Class', 'Social Concept'),
#  ('Stormwind Assassins', 'Fiction (Character/Group)'),
#  ('Architecture', 'Scientific Concept'),
#  ('Warcraft', 'Game'),
#  ('Spells for Hire', 'Title'),
#  ('soldiers', 'Person'),
#  ('Campaign', 'Social Concept'),
#  ('Troggs', 'Band'),
#  ('Conditions', 'Social Concept'),
#  ('rugged wilderness', 'Geographic Feature'),
#  ("Sword & Sorcery's Advanced Player's Guide", 'Book'),
#  ('Night Elf Druid',
#   'Character (from the list, the closest match would be Person or Title, but Night Elf Druid is a specific character from a game, thus Character seems to be the most appropriate.)'),
#  ('Open Game License', 'Legal Code'),
#  ('Frostsaber cats', 'Social Concept'),
#  ('high elves',
#   "Fantasy Race (Not in provided list, but it can be categorized as a subcategory under 'Fantasy' which is not listed)"),
#  ('Number', 'Number'),
#  ('dwarven patrols', 'Social Concept'),
#  ('Numerous Tunnels', 'Geographic Feature'),
#  ('Table 1-1: Ability Modifiers', 'Section'),
#  ('Aegwgnn', 'File Name'),
#  ('Trade Skill Equivalents', 'Scientific Concept'),
#  ('The Arena', 'Venue (Facility)'),
#  ('PC', 'Facility'),
#  ('Citizen', 'Person'),
#  ('Deep Learning', 'Scientific Concept'),
#  ('Dwarf', 'Social Concept'),
#  ('Communitγ Reputation Score Bonuses', 'Social Concept'),
#  ('Night Elf',
#   "Fantasy Race (not included in the provided list, but can be considered as an extension or sub-category under 'Scientific Concept' or 'Social Concept', but it is more accurately described as a fictional character type)"),
#  ('Citizens', 'Person'),
#  ('Black Morass', 'Geographic Feature'),
#  ('Technological Devices', 'Technology (Facility, Instrument)'),
#  ('Horde', 'Social Concept'),
#  ('rogue Horde bands', 'Social Concept'),
#  ('Undead Forsaken', 'Title (fictional character or concept)'),
#  ('Hero', 'Person'),
#  ('Goods', 'Geographic Feature or Facility (depending on context)'),
#  ("Lich King's crown", 'Fictional Item'),
#  ('Blasted Lands', 'Geographic Feature'),
#  ('Combat', 'Battle'),
#  ('Malfurion',
#   'Title (or Character, if referring to a character from a game or book)'),
#  ('Racial Tensions', 'Social Concept'),
#  ('Theramore Island', 'Geographic Feature'),
#  ('graveyards', 'Geographic Feature'),
#  ('Elwynn Forest', 'Geographic Feature'),
#  ('Craggy Mountains', 'Geographic Feature'),
#  ('New Concepts', 'Social Concept'),
#  ('The Commoner (Com)', 'Title'),
#  ('Hit Die', 'Game Mechanism'),
#  ('Spellcraft', 'Social Concept'),
#  ('Black dragons', 'Social Concept'),
#  ('Ocean', 'Geographic Feature'),
#  ('older Alliance', 'Historical Event'),
#  ('Warrior', 'Person'),
#  ('Great Sea', 'Geographic Feature'),
#  ('Terminology', 'Social Concept'),
#  ('Dark Portal', 'Geographic Feature'),
#  ('Warlock Spells', 'Social Concept'),
#  ("Grim Batol's great walls and spires", 'Geographic Feature'),
#  ('Furbolg', 'Fantasy Race (not explicitly listed, but closest category)'),
#  ('heartland', 'Geographic Feature'),
#  ('Hire Transport', 'Facility'),
#  ('Mike Johnstone', 'Person'),
#  ('Hippogriff', 'Social Concept'),
#  ('Game Mechanics', 'Theoretical Model'),
#  ('bandits', 'Social Concept'),
#  ('Arcane Communitγ (Aco)', 'Research Group'),
#  ('Adventurer', 'Person'),
#  ('Demon', 'Social Concept'),
#  ('Grim Batol', 'Geographic Feature'),
#  ('Shaman', 'Person'),
#  ('Tomb of Sargeras', 'Geographic Feature'),
#  ('Modifier', 'Algorithm'),
#  ("Sargeras' tomb", 'Geographic Feature'),
#  ('Protruding rocks', 'Geographic Feature'),
#  ('Fel-Sworn', 'Title'),
#  ('Ironforge Dwarves',
#   'Fiction Character (not in provided categories, but closest match)'),
#  ('Familiar Abilities Master Level', 'Title'),
#  ('NPCs', 'Social Concept'),
#  ('Stormwind', 'City'),
#  ('Elven Ranger Favored Enemies', 'Social Concept'),
#  ('Malfunction Effects',
#   'Phenomenon (not explicitly listed, but closest match to describe a series of effects due to an event)'),
#  ('The Religious Communitγ (Rco)', 'Research Group'),
#  ('modifier', 'Algorithm'),
#  ('Shields', 'Geographic Feature'),
#  ('d6', 'Mathematical Function'),
#  ('Draenor', 'Fantasy Realm'),
#  ('Priest Spells', 'Social Concept'),
#  ('Slaughtered', 'Historical Event'),
#  ('Chapter 18: Campaigns', 'Chapter'),
#  ('inhospitable', 'Social Concept'),
#  ('Tom Jung', 'Person'),
#  ('Tea Rooms', 'Facility'),
#  ('Ironforge dwarves', 'Character (Fictional)'),
#  ('The Undead', 'Social Concept'),
#  ('Team', 'Social Concept'),
#  ('Goblin', 'Social Concept'),
#  ('Hruon Firesinger', 'Person'),
#  ('Assassin Spell Slots per Day', 'Algorithm'),
#  ('artifacts', 'Geographic Feature'),
#  ("Ner'zhul", 'Character'),
#  ('Weight', 'Scientific Concept'),
#  ('Cultural Revolution', 'Social Concept'),
#  ('Immortality', 'Scientific Concept'),
#  ('Kul Tiras navγ', 'Geographic Feature'),
#  ('Blackrock Orcs',
#   "Title (Assuming it's a title of something, given the context doesn't suggest otherwise)"),
#  ('Orgrimmar', 'City'),
#  ('Renegade orcs', 'Fantasy Character (not listed, but closest match)'),
#  ('Bottom Line', 'Symbolic Expression'),
#  ('Bsr', 'File Name'),
#  ('shipwards', 'Geographic Feature'),
#  ('The Wetlands', 'Geographic Feature'),
#  ('The Scout', 'Title'),
#  ('Third War', 'War'),
#  ('Technological device creation rules', 'Algorithm'),
#  ('Locked Iron Door', 'Physical Item'),
#  ('Bloodlust', 'Social Concept'),
#  ('Mage Spells', 'Social Concept'),
#  ('Stamina (Sta)', 'Symbolic Expression'),
#  ('King Anduin Wrγnn', 'title'),
#  ('Ashenvale Forest', 'Geographic Feature'),
#  ('Demonic spirits', 'Social Concept'),
#  ('cosmology', 'Scientific Concept'),
#  ('Darkshore', 'Geographic Feature'),
#  ('Center of Dwarven Culture', 'City or Geographic Feature'),
#  ('Math', 'Scientific Concept'),
#  ('Historgy and gazetteer', 'System of Knowledge'),
#  ('Mage', 'title'),
#  ('World of Warcraft the Roleplaying Game', 'Game'),
#  ('Settlements', 'Geographic Feature'),
#  ('divine magic', 'Social Concept'),
#  ('Paladin Spells', 'Algorithm'),
#  ('East', 'Geographic Feature'),
#  ('debaucherγ', 'Symbolic Expression'),
#  ('Andrew Bates', 'Person'),
#  ('Truce', 'Social Concept'),
#  ('Abilities', 'Social Concept'),
#  ('Holγ Light', 'Scientific Concept'),
#  ('Races', 'Social Concept'),
#  ('Thunder Bluff', 'City'),
#  ('Mount Hγjal', 'Geographic Feature'),
#  ('new homeland', 'Country or Geographic Feature'),
#  ('Feature Extraction', 'Algorithm'),
#  ('Blackwater Raiders', 'Company'),
#  ('Arthaus', 'Company'),
#  ('game concepts', 'Social Concept'),
#  ('Services', 'Service (as a Social Concept or Facility)'),
#  ('Craggy', 'Geographic Feature'),
#  ('Admiral', 'title'),
#  ('Nefarion',
#   "Title (assuming it's a character or entity from media, games, etc.)"),
#  ('Living trees called ancients', 'Geographic Feature'),
#  ('Perpetual summer twilight', 'Social Concept'),
#  ('Barrow Dens', 'Geographic Feature'),
#  ('Elf', 'title'),
#  ('Height', 'Scientific Concept'),
#  ('demons local to Sargeras', 'Scientific Concept'),
#  ('Alliance & Horde Compendium', 'Book'),
#  ('Cult of the Damned', 'Social Concept'),
#  ('Hot', 'Social Concept'),
#  ('Racial Abilitγ Modifi ers', 'Scientific Concept'),
#  ('Ships', 'Geographic Feature'),
#  ('The Aristocrat (Ari)', 'title'),
#  ('Warcraft Computer Games', 'Game'),
#  ('war experiences', 'Social Concept'),
#  ('Game', 'Social Concept'),
#  ("Explorer's Guild", 'Company'),
#  ('Roleplaying Game', 'Social Concept'),
#  ('goblin citγ', 'Pseudocode'),
#  ('Scourge', 'Social Concept'),
#  ('Mounts and Related Gear', 'Geographic Feature'),
#  ('Demon Blood', 'Symbolic Expression'),
#  ('MM', 'File Name'),
#  ('Difficulty Class (DC)', 'Algorithm'),
#  ('Alexstrasza', 'Character (from World of Warcraft lore)'),
#  ('warriors', 'Social Concept'),
#  ('Transfer Learning', 'Theoretical Model'),
#  ('Winterspring Valle', 'Geographic Feature'),
#  ('Alliance', 'Social Concept'),
#  ('Mike Tinneγ', 'title'),
#  ("Character's Skill List", 'Social Concept'),
#  ('Durotar', 'City'),
#  ("Stormwind's territorγ", 'Geographic Feature'),
#  ('World of Warcraft MMORPG', 'Game'),
#  ('fi sh', 'Geographic Feature'),
#  ('Goblin Merchants', 'Social Concept'),
#  ('The Burning Steppes', 'Geographic Feature'),
#  ('Blue dragons', 'Social Concept'),
#  ('Vital Statistics', 'Social Concept'),
#  ('Spell slot system', 'Algorithm'),
#  ('The Tauren',
#   'Character (from the context, it seems to be a fictional race from World of Warcraft)'),
#  ('Bootyg Bay', 'Geographic Feature'),
#  ('The Arcane Communitγ (Aco)', 'Research Group'),
#  ('sea giants', 'Geographic Feature'),
#  ('PCs', 'Computer (As a Facility, Institution, or Tool)'),
#  ('Upper Levels', 'Geographic Feature'),
#  ('Communitγ Wealth Level', 'Social Concept'),
#  ('Maelstrom', 'Geographic Feature'),
#  ('Uldaman', 'Geographic Feature'),
#  ('Independent caravans', 'Social Concept'),
#  ('Jaina', 'Historical Event'),
#  ('Healer Spell Slots per Day', 'Pseudocode'),
#  ('Cenarius',
#   'Fantasy Character (not in provided categories, but closest match)'),
#  ('Dark Iron dwarves', 'Fantasy Race'),
#  ('Renegade Brethren', 'Social Concept'),
#  ('Northrend', 'Continent'),
#  ('Prepared Spells', 'Magical Concept'),
#  ('newer Alliance',
#   "Organization (assuming it's a reference to an alliance as a group or association)"),
#  ("Stormwind's territory", 'Geographic Feature'),
#  ('Warriors', 'Social Concept'),
#  ('Lands of Mysterery', 'Geographic Feature'),
#  ('Community Rules', 'Social Concept'),
#  ('Gender', 'Social Concept'),
#  ('Kobolds', 'Fantasy Creature'),
#  ('GM', 'Company'),
#  ('Hlr', 'File Name'),
#  ('Silithid', 'Scientific Concept'),
#  ('wild creatures', 'Geographic Feature'),
#  ('tauren',
#   'Social Concept (or possibly, if referring to a specific game, Facility or Instrument)'),
#  ("Kalimdor's north coast", 'Geographic Feature'),
#  ('Rob Baxter', 'Person'),
#  ('thunder lizards', 'Social Concept'),
#  ('Orc Shamans', 'Social Concept'),
#  ('Brothels', 'Social Concept'),
#  ('Grand Admiral Daelin Proudmoore', 'Person'),
#  ("Dwarves' Lofty Origins", 'Title'),
#  ('Loggers',
#   'Occupation (if specific to people) or Facility (if specific to a place where logging operations occur)'),
#  ('Hit Points', 'Mathematical Function'),
#  ('secret power', 'Social Concept'),
#  ('Frostmane trolls', 'Fantasy Creature'),
#  ('Outland', 'Geographic Feature'),
#  ('centaur', 'Scientific Concept'),
#  ('rains', 'Weather Phenomenon'),
#  ('Scout', 'Person'),
#  ('victor', 'Person'),
#  ('matt milberger', 'Person'),
#  ('Die Roll', 'Game or Simulation Element'),
#  ('Gladiatorial Arenas', 'Geographic Feature'),
#  ('Titan ruin', 'Geographic Feature'),
#  ('Inhospitable', 'Social Concept'),
#  ('Madness', 'Social Concept'),
#  ('civil war', 'War'),
#  ('caravans', 'Geographic Feature'),
#  ('Kaldorei',
#   'Fantasy Race (not listed, but could be considered as an extension or addition to the given categories)'),
#  ('Villages and Towns', 'Geographic Feature'),
#  ('trade routes', 'Geographic Feature'),
#  ('Warcraft universe', 'Fictional Universe'),
#  ('Blackrock Spire', 'Geographic Feature'),
#  ('The High Elf', 'Character'),
#  ('Transport Ships', 'Facility'),
#  ('Azshara', 'Mythological Figure'),
#  ('Harpies', 'Mythological Creature'),
#  ('The Civilian Communitγ (Cco)', 'Government Body'),
#  ('Thrall', 'Title (historical character)'),
#  ('Wormbog',
#   'Fictional Entity (not explicitly listed, but it seems most appropriate for a made-up creature or place)'),
#  ('Physical Appearance', 'Social Concept'),
#  ('Ability Modifiers', 'Mathematical Function'),
#  ('Feats', 'Social Concept'),
#  ('Background', 'Geographic Feature'),
#  ('Centaur', 'Mythological Creature'),
#  ('quilboar tribes', 'Social Concept'),
#  ('Samwise Didier', 'Person'),
#  ('tauren tribe', 'Social Concept'),
#  ('Amnesty', 'Social Concept'),
#  ('Ege of Sargeras', 'Fictional Entity (not listed, but closest match)'),
#  ('underground', 'Geographic Feature'),
#  ('Bandits', 'Social Concept'),
#  ('demons kill', 'Social Concept'),
#  ('Tirisfal', 'Geographic Feature'),
#  ('Iron Forge', 'Facility'),
#  ('Tainted moonwells', 'Geographic Feature'),
#  ('Archmage of Kirin Tor', 'title'),
#  ('Character Sheet', 'Article'),
#  ('demons', 'Social Concept'),
#  ('Frostmane Trolls', 'Fantasy Creature'),
#  ('Armor', 'Physical Item'),
#  ('Carrγing Capacitγ', 'Mathematical Function'),
#  ('Adventuring Gear', 'Facility'),
#  ('Rock golems', 'Social Concept'),
#  ('Strength (Str)', 'Scientific Concept'),
#  ('Native Species', 'Scientific Concept'),
#  ('World of Warcraft the RPG', 'Game'),
#  ('Duelist', 'Person'),
#  ('Nine races (gnomes, jungle trolls, undead Forsaken)',
#   'Fantasy Character (a subcategory within Person)'),
#  ('Manag', 'Algorithm'),
#  ('Gra G Mountains', 'Geographic Feature'),
#  ('Mount', 'Geographic Feature'),
#  ('First War', 'War'),
#  ('Beastmaster', 'title'),
#  ('Citγ', 'Symbolic Expression'),
#  ("Gul'dan", 'Character (from the fictional world)'),
#  ('OGL route', 'Route'),
#  ('Forgetten', 'Social Concept'),
#  ('Asn', 'Alphabetical Symbol (Acronym)'),
#  ("Stormwind's people",
#   'Person (assuming Stormwind refers to a group or community with people associated)'),
#  ('Buildings', 'Geographic Feature'),
#  ('Arcane Magic', 'Social Concept'),
#  ('Druids', 'Social Concept'),
#  ('Aedelas Blackmoore', 'Person'),
#  ('Dwarven Marksmen', 'Character (Fiction)'),
#  ('Warchief', 'Title'),
#  ('Gnolls', 'Fantasy Creature'),
#  ('Actions in Combat', 'Battle'),
#  ('Communitγ Defense Score Bonuses', 'Social Concept'),
#  ('Mountainous', 'Geographic Feature'),
#  ('human settlement', 'Geographic Feature'),
#  ('Port', 'Geographic Feature'),
#  ('Time of Day', 'Social Concept'),
#  ('More Exotic Means', 'Symbolic Expression'),
#  ('Table 2-4: The Night Elf',
#   'Table\n\nTerm: "United Nations"\nCategory: Government Body\n\nTerm: "Microsoft"\nCategory: Company\n\nTerm: "Quantum Physics"\nCategory: Scientific Concept\n\nTerm: "Einstein"\nCategory: Person\n\nTerm: "Marine Biology Research Group"\nCategory: Research Group\n\nTerm: "Capitalism"\nCategory: Social Concept\n\nTerm: "General Relativity"\nCategory: Theoretical Model\n\nTerm: "New York City"\nCategory: City\n\nTerm: "Europe"\nCategory: Continent\n\nTerm: "Grand Canyon"\nCategory: Geographic Feature\n\nTerm: "CERN"\nCategory: Facility\n\nTerm: "University of Oxford"\nCategory: Institution\n\nTerm: "The Great Gatsby (Book)"\nCategory: Book\n\nTerm: "Chapter 2 (Section)"\nCategory: Section\n\nTerm: "Constitution (Law)"\nCategory: Law\n\nTerm: "Legal Code 1980"\nCategory: Legal Code\n\nTerm: "Report_2021.pdf (File Name)"\nCategory: File Name\n\nTerm: "Hypothesis Testing Algorithm"\nCategory: Algorithm\n\nTerm: "Laser Printer (Tool/Instrument)"\nCategory: Tool\n\nTerm: "Sodium Chloride (Chemical)"\nCategory: Chemical\n\nTerm: "World War II (Historical Event)"\nCategory: Historical Event\n\nTerm: "DNA Discovery (Scientific Discovery)"\nCategory: Scientific Discovery\n\nTerm: "Titanic Accident (Accident/Disaster)"\nCategory: Accident\n\nTerm: "Steps 1-3 (Steps in a Method)"\nCategory: Steps in a Method\n\nTerm: "Photosynthesis (Biological Process)"\nCategory: Biological Process\n\nTerm: "Combustion (Chemical Process)"\nCategory: Chemical Process\n\nTerm: "Manufacturing Process (Industrial Process)"\nCategory: Industrial Process\n\nTerm: "Physics (Academic Field)"\nCategory: Academic Field\n\nTerm: "Sci-Fi (Genre)"\nCategory: Genre\n\nTerm: "Classification System (System of Knowledge)"\nCategory: System of Knowledge\n\nTerm: "2021-03-15 (Date)"\nCategory: Date\n\nTerm: "Week (Duration/Period)"\nCategory: Duration\n\nTerm: "Kilogram (Unit)"\nCategory: Unit\n\nTerm: "50-100 mph (Range)"\nCategory: Range\n\nTerm: "NASA (Acronym)"\nCategory: Acronym\n\nTerm: "Experiment Label"\nCategory: Label\n\nTerm: "Significance Keyword"\nCategory: Keyword\n\nTerm: "Patent No. 1234567 (Patent)"\nCategory: Patent\n\nTerm: "Nuclear Power Plant (Technical System)"\nCategory: Technical System'),
#  ('Ironforge Dwarf', 'Character (Person)'),
#  ('Sword and Sorcerγ Studio', 'Company'),
#  ('Well of Eternity', 'Geographic Feature'),
#  ('Neural Networks', 'Scientific Concept'),
#  ('Wolves', 'Animal'),
#  ('Warcraft games', 'Game'),
#  ('battles over land', 'Battle'),
#  ('Warlocks', 'Social Concept'),
#  ("Kil'jaeden", 'Fiction Character'),
#  ('Ancient', 'Historical Event'),
#  ('Tergande Whisperwind', 'Title'),
#  ('Resources', 'Resource'),
#  ('Stormwind Citγ', 'City'),
#  ('Mur Laffertγ', 'Title'),
#  ('bloodlust rage', 'Social Concept'),
#  ('Jungle', 'Geographic Feature'),
#  ('Character Creation', 'Social Concept'),
#  ('Blackhand the Destroger', 'title'),
#  ('Ship', 'Geographic Feature'),
#  ('Fallow land', 'Geographic Feature'),
#  ('King Terenas', 'Person'),
#  ('Brom', 'Chemical'),
#  ('Stormwind Keep', 'Geographic Feature'),
#  ('Injury', 'Social Concept'),
#  ('night elves',
#   'Fantasy Race (not included in the provided categories, but closest match)'),
#  ('Titan Artifacts', 'Artifacts (as a type of Physical Item)'),
#  ('Arcana Unearthed', 'Book'),
#  ('Skill Points per Level', 'Mathematical Function'),
#  ('Forest Canopy', 'Geographic Feature'),
#  ('Rog', 'Person'),
#  ('Jaina Proudmoore', 'Person'),
#  ('Durotan', 'Character'),
#  ('Chapter 2: Races', 'Chapter'),
#  ('Weight Limit', 'Physical Item'),
#  ('Jose Aello', 'Person'),
#  ("world's history", 'Social Concept'),
#  ("Durotar (orcs' territor)", 'Geographic Feature'),
#  ('Religious Communitγ (Rco)', 'Social Concept'),
#  ('Lordaeron', 'City'),
#  ('High Bluffs', 'Geographic Feature'),
#  ('Wildhammer dwarves', 'Race (Fantasy Fiction)'),
#  ('Tent Cities', 'City'),
#  ('Warcraft Campaigns',
#   'Game\n\nExplanation: Warcraft Campaigns is a series of campaigns in the video game series Warcraft, developed by Blizzard Entertainment. While it could be argued that it falls under several categories such as Academic Field (for strategy gaming studies), Classification (within the context of the games themselves), or even Historical Event (as they depict fictional historical events), "Game" is the most appropriate category for the term Warcraft Campaigns in this context.'),
#  ('Sct', 'Label'),
#  ('Shaman Spells', 'Social Concept'),
#  ('Necromancer', 'Title'),
#  ('Sacred Forests', 'Geographic Feature'),
#  ('Slinking Wolves', 'Social Concept'),
#  ('ships', 'Geographic Feature'),
#  ('Wyvern', 'Mythical Creature'),
#  ('Magic', 'Social Concept'),
#  ('Travelers', 'Social Concept'),
#  ('Hunter', 'Person'),
#  ('Illidan Stormrage', 'Character'),
#  ('The Jungle Troll', 'Social Concept'),
#  ('Validation Set',
#   'Data Set (or more specifically, a subset of a dataset used for validation purposes)'),
#  ('tranquility', 'Social Concept'),
#  ('Centaur raiding parties', 'Social Concept'),
#  ('characters', 'Social Concept'),
#  ('Shadow Council', 'Social Concept'),
#  ('orc stronghold', 'Geographic Feature'),
#  ('other affi liations',
#   'Multiple Affiliations (not directly listed, but can be considered as a Label or Keyword)'),
#  ('foolhardy actions', 'Social Concept'),
#  ('Nightsaber', 'Fantasy Creature'),
#  ('King Magni Bronzebeard', 'Character (Person)'),
#  ('Random Height and Weight', 'Scientific Concept'),
#  ('Necromancers', 'Social Concept'),
#  ('Darkshire', 'City'),
#  ('Communitγ Abilitγ Score Cost', 'Scientific Concept'),
#  ('Endless Sands', 'Geographic Feature'),
#  ('Tanaris Desert', 'Geographic Feature'),
#  ('Chris Metzen', 'Person'),
#  ('dwarves', 'Social Concept'),
#  ('Moonglade Forest Creatures', 'Social Concept'),
#  ('Swamp of Sorrows', 'Geographic Feature'),
#  ('Salt deposits', 'Geographic Feature'),
#  ('War Fleets',
#   'War\n\nHere\'s a brief explanation for those who are curious: "War Fleets" refers to naval forces assembled by a country or alliance during warfare, making it fall under the "War" category.'),
#  ('Spellcasting', 'Social Concept'),
#  ('Multi-Class', 'Algorithm'),
#  ('Trail Rations', 'Facility'),
#  ('Defias Brotherhood', 'Company'),
#  ('divine nature magic', 'Social Concept'),
#  ('Felwood', 'Geographic Feature'),
#  ('steel-graγ skγ', 'Symbolic Expression'),
#  ('Bill Petras', 'Person'),
#  ('Anduin Lothar', 'Person'),
#  ('greater power', 'Social Concept'),
#  ('Renegade humans', 'Social Concept'),
#  ('violence', 'Social Concept'),
#  ('Defenses', 'Military Battle'),
#  ('Azeroth',
#   'Fantasy World (not included in provided categories, but can be considered as a System of Knowledge or a Geographic Feature)'),
#  ('Racial Levels', 'Social Concept'),
#  ('Shipwards', 'Facility'),
#  ('Draenei',
#   'Fantasy Race (Not present in the given categories, but it can be categorized as such)'),
#  ('Player', 'Person'),
#  ('Ability Scores', 'Scientific Concept'),
#  ('Orcs',
#   'Fictional Entity (not in provided categories, but can be included as an extension)'),
#  ('Demonic energy', 'Scientific Concept'),
#  ('WarcraftRPG.com', 'Company'),
#  ('The First War', 'Historical Event'),
#  ('Dice', 'Physical Item'),
#  ('Barrens', 'Geographic Feature'),
#  ('Kile', 'File Name'),
#  ('Spirit', 'Social Concept'),
#  ('World of Warcraft', 'Game'),
#  ('Martial Prowess', 'Social Concept'),
#  ('Enchanted land', 'Social Concept'),
#  ('Militia', 'Government Body'),
#  ('Primarilγ', 'Symbolic Expression'),
#  ('Alliance heroes',
#   'Character (from the context, it seems to be a group of characters or entities)'),
#  ('Warcraft computer games', 'Game'),
#  ('dustγ landscape', 'Geographic Feature'),
#  ('Pirate Vessels', 'Geographic Feature'),
#  ('Bbn', 'File Name'),
#  ('Venture Companγ', 'Company'),
#  ('Frostwolf clan', 'Social Concept'),
#  ('Graveyards', 'Geographic Feature'),
#  ('Roman Kenneγ', 'Person'),
#  ('Menethil Harbor', 'City'),
#  ('d20', 'Physical Item'),
#  ('Creature Size and Scale', 'Social Concept'),
#  ('Healer Spells', 'Social Concept'),
#  ('Dwarves', 'Social Concept'),
#  ('other races', 'Social Concept'),
#  ('Carlo Arellano', 'Person'),
#  ('Medivh', 'Character (from the fictional universe)'),
#  ('Settlement', 'Geographic Feature'),
#  ('Admiral Proudmoore', 'Person'),
#  ('Two-Weapon Fighting Penalties', 'Algorithm'),
#  ('Restaurants', 'City (or Geographic Feature)'),
#  ('Forbidding', 'Social Concept'),
#  ('Warcraft Game', 'Game'),
#  ('jungle trolls', 'Social Concept'),
#  ('Fishers', 'City'),
#  ('Affiliations', 'Institution'),
#  ('Possible War Experiences', 'Social Concept'),
#  ('Saboteurs', 'Social Concept'),
#  ('Everday Farmer and Merchant', 'Person'),
#  ('Theramore', 'City'),
#  ('Image Processing', 'Theoretical Model'),
#  ('Random Starting Ages', 'Social Concept'),
#  ('Age', 'Social Concept'),
#  ('Shamanistic culture', 'Social Concept'),
#  ('Desolace', 'Geographic Feature'),
#  ('Nighthaven', 'Geographic Feature'),
#  ('Hjal Summit', 'Geographic Feature'),
#  ('Dust devils', 'Geographic Feature'),
#  ('Settings', 'Interface Element'),
#  ('Metropolis', 'City'),
#  ('Skills', 'Social Concept'),
#  ('nature-loving', 'Social Concept'),
#  ('Rich agricultural center', 'Geographic Feature'),
#  ('Hard Work', 'Social Concept'),
#  ('Tγrande Whisperwind', 'Title'),
#  ('Hero points system', 'Game Mechanism'),
#  ('Badlands', 'Geographic Feature'),
#  ('Titan Artifact', 'Artifact'),
#  ('The Soldier (Sol)', 'Title'),
#  ('law', 'Law'),
#  ('Abilities and Conditions', 'Social Concept'),
#  ('Lost Temple', 'Geographic Feature'),
#  ('Duskwood', 'Geographic Feature'),
#  ('GMs', 'Company'),
#  ('Same Rules System', 'Theoretical Model'),
#  ('Ysera', 'Mythical Creature'),
#  ('Current Climate', 'Scientific Concept'),
#  ('Patience', 'Social Concept'),
#  ('Test Set', 'Data Set'),
#  ('Stonewatch Keep', 'Geographic Feature'),
#  ('Bears', 'Geographic Feature'),
#  ("characters' backgrounds", 'Social Concept'),
#  ('Drake', 'Person'),
#  ('raiding parties', 'War'),
#  ('The Militarγ Communitγ (Mco)', 'Research Group'),
#  ('World of Warcraft (RPG)', 'Game'),
#  ('Darkspear Trolls',
#   'Tribal Group (not explicitly listed, but can be grouped under "Social Concept")'),
#  ('Murlocs', 'Fantasy Creature'),
#  ('ogres', 'Social Concept'),
#  ('Timber', 'Geographic Feature'),
#  ('humans', 'Person'),
#  ('Affiliation', 'Social Concept'),
#  ('Hero Points', 'Symbolic Expression'),
#  ('Tkr', 'Label'),
#  ('citizens', 'Person'),
#  ('Description', 'Section'),
#  ('Chimera', 'Scientific Concept'),
#  ('Sword and Sorcerγ', 'Title'),
#  ('Warlock', 'title'),
#  ('Open Game License (OGL)', 'Legal Code'),
#  ('patriotism', 'Social Concept'),
#  ('Explosives and Gunpowder', 'Chemical'),
#  ('Gnome', 'Social Concept'),
#  ('necromancers', 'Social Concept'),
#  ('High', 'Number'),
#  ('demon blood', 'Supernatural Concept'),
#  ('Human forces', 'Social Concept'),
#  ('Spell slots-based magic system', 'Theoretical Model'),
#  ('rockγ area', 'Geographic Feature'),
#  ('Foothold Citadel', 'Facility'),
#  ('goals', 'Social Concept'),
#  ('Orgrim Doomhammer', 'Person'),
#  ('Populace', 'Social Concept'),
#  ('Caravan', 'Geographic Feature'),
#  ('Donning Armor', 'Social Concept'),
#  ('Worgen', 'Fantasy Creature'),
#  ('Dwarven Patrols', 'Social Concept'),
#  ('Character Wealth bγ Level', 'Scientific Concept'),
#  ('Loch Modan', 'Geographic Feature'),
#  ('Equipment', 'Facility'),
#  ('Twisting Nether', 'Fantasy Concept'),
#  ('West', 'Continent'),
#  ('Name', 'Person'),
#  ('Other Settings', 'System of Knowledge'),
#  ('mood', 'Social Concept'),
#  ('Warcraft RPG', 'Game'),
#  ('Underground Passages', 'Geographic Feature'),
#  ('Colonization', 'Social Concept'),
#  ('Satyrs', 'Social Concept'),
#  ("Sargeras' spirit", 'Title (fictional entity from a work of fiction)'),
#  ('Manual of Monsters', 'Book'),
#  ('Unexplored', 'Social Concept'),
#  ('The World of Warcraft RPG', 'Game'),
#  ('Severe Winds', 'Weather Phenomenon'),
#  ('Pre-trained Models', 'Theoretical Model'),
#  ('Guardians of Tirisfal', 'Title (Fictional Entity)'),
#  ('Troll', 'Social Concept'),
#  ('Pal', 'title'),
#  ('Warchief Thrall', 'Character'),
#  ('Tinγ and Large Weapon Damage', 'Scientific Concept'),
#  ('warlocks', 'Social Concept'),
#  ('Arathor',
#   'Fantasy Realm (not explicitly provided in the list, but it can be categorized as a Geographic Feature or City within a System of Knowledge or Classification)'),
#  ('Extreme', 'Social Concept'),
#  ('Lich King', 'Title (Fictional character)'),
#  ('Fen', 'Geographic Feature'),
#  ('Outpost', 'Facility'),
#  ('Blackhand the Destroyer', 'Title'),
#  ('Character Classes', 'Algorithm'),
#  ('Crstal Lakes', 'Geographic Feature'),
#  ('Nozdormu', 'Title (Character from Warcraft universe)'),
#  ('Mulgore', 'Geographic Feature'),
#  ('Stewart Wieck', 'Person'),
#  ('Chapter 7: Description', 'Section'),
#  ('gnomes', 'Social Concept'),
#  ('The Forsaken', 'Title'),
#  ('Sunwell', 'Geographic Feature'),
#  ('bγ rich parents', 'Social Concept'),
#  ('Paladin', 'Title (fictional character)'),
#  ('dragons', 'Social Concept'),
#  ('Attack Roll Modifi ers', 'Algorithm'),
#  ('Brackish water', 'Geographic Feature'),
#  ('Percentile dice', 'Mathematical Function'),
#  ('Ragnaros the Fire Lord', 'title'),
#  ('Eastern Lands', 'Geographic Feature'),
#  ('massive fortress', 'Geographic Feature'),
#  ('trogg band', 'Music Group'),
#  ('Items Affected bγ Magical Attacks', 'Social Concept'),
#  ('Arcanist Spell Slots per Day', 'Pseudocode'),
#  ('Shops', 'City or Geographic Feature'),
#  ('Travel', 'Social Concept'),
#  ('Shadows & Light', 'Social Concept'),
#  ('Experience', 'Social Concept'),
#  ('Semi Kim', 'title'),
#  ('Tracking Modifiers', 'Algorithm'),
#  ('Charisma (Cha)', 'Social Concept'),
#  ('Accusations', 'Social Concept'),
#  ('Forsaken', 'Social Concept'),
#  ('Independent', 'Social Concept'),
#  ('Towns', 'City'),
#  ('east', 'Geographic Feature'),
#  ('Admiral Daelin Proudmoore', 'Person'),
#  ('Manγ Ironforge strongholds', 'Geographic Feature'),
#  ('Cloudless Skies', 'Geographic Feature'),
#  ('Berserker', 'Mythical Character'),
#  ('Deadwind Pass (region)', 'Geographic Feature'),
#  ('dwarven marksmen', 'Character (Fictional)'),
#  ('d4', 'File Name'),
#  ('Crops', 'Agricultural Concept'),
#  ('Racial Class', 'Social Concept'),
#  ('World Tree', 'Geographic Feature'),
#  ('Seth Johnson', 'Person'),
#  ("Lich King's throne", 'Fictional Item'),
#  ('Auberdine', 'Person'),
#  ('Ogres', 'Social Concept'),
#  ('fight', 'Battle'),
#  ('war',
#   'War\n\nTerm: "Darwinism"\nCategory: Scientific Concept\n\nTerm: "Department of Justice"\nCategory: Government Body\n\nTerm: "NASA"\nCategory: Company\n\nTerm: "The Great Gatsby"\nCategory: Book\n\nTerm: "Quantum Mechanics"\nCategory: Theoretical Model\n\nTerm: "New York City"\nCategory: City\n\nTerm: "Mount Everest"\nCategory: Geographic Feature\n\nTerm: "Europe"\nCategory: Continent\n\nTerm: "United Nations"\nCategory: International Organization (Not explicitly listed, but it can be considered a Government Body for the purpose of this task)\n\nTerm: "Python" (the programming language)\nCategory: Algorithm (or Programming Language, if you prefer)\n\nTerm: "Equation of Time"\nCategory: Mathematical Function\n\nTerm: "Steps in a Method"\nCategory: Steps in a Method\n\nTerm: "Photosynthesis"\nCategory: Biological Process\n\nTerm: "Chemical Reaction"\nCategory: Chemical Process\n\nTerm: "Industrial Revolution"\nCategory: Historical Event\n\nTerm: "Theory of Relativity"\nCategory: Theoretical Model\n\nTerm: "Evolution" (biology)\nCategory: Scientific Concept\n\nTerm: "Einstein\'s Theory of General Relativity"\nCategory: Theoretical Model\n\nTerm: "The Big Bang Theory"\nCategory: Scientific Concept\n\nTerm: "String Theory"\nCategory: Theoretical Model\n\nTerm: "Algebraic Topology"\nCategory: Academic Field\n\nTerm: "Machine Learning"\nCategory: Academic Field\n\nTerm: "Deep Blue"\nCategory: Computer Program (or Pseudocode, if you prefer)\n\nTerm: "The Law of Conservation of Energy"\nCategory: Physical Law\n\nTerm: "Internet"\nCategory: Technical System\n\nTerm: "HTML"\nCategory: Markup Language\n\nTerm: "PyTorch"\nCategory: Machine Learning Framework (or Library, if you prefer)\n\nTerm: "GitHub"\nCategory: Web-based Platform (or Hosting Service, if you prefer)'),
#  ('Undead', 'Social Concept'),
#  ('Bedrolls', 'Geographic Feature'),
#  ('mortal races', 'Social Concept'),
#  ('target number', 'Number'),
#  ('Goblin Watchmen', 'Title'),
#  ('The Night Elf',
#   'Character (from the System of Knowledge, specifically Genre - Fantasy)'),
#  ('Social Economic Strata', 'Social Concept'),
#  ('Dwarven Architecture', 'Social Concept'),
#  ('Monster', 'Social Concept'),
#  ('Lich', 'Fantasy Character'),
#  ('Community generation rules', 'Algorithm'),
#  ('Adventures', 'Social Concept'),
#  ('Atmosphere for a Warcraft game', 'Social Concept'),
#  ('demonic influence', 'Social Concept')]

# %%
nodes = {
    "node" : 0,
    "type" : 0,
    "topic" : 0
}
